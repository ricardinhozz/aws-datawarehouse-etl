# %%
import pandas as pd
import requests

# %%
url = f'https://api.weatherbit.io/v2.0/history/hourly?city=SaoPaulo&start_date=2025-11-18&end_date=2025-11-19&key=3361e8eba2044015857b77de8707c200'
response = requests.get(url)
response.raise_for_status()
data = response.json()

# %%
hourly_data = data.get("data", [])

if not hourly_data:
    print("No hourly data found!")
    df = pd.DataFrame()
else:
    df = pd.DataFrame(hourly_data)
    
    columns_to_keep = [col for col in ["datetime", "app_temp", "temp", "weather"] if col in df.columns]
    df = df[columns_to_keep]
    
    if "weather" in df.columns:
        weather_df = pd.json_normalize(df["weather"])
        df = df.drop(columns=["weather"]).join(weather_df)
    
    top_level_cols = {
        "city": data.get("city_name"),
        "lat": data.get("lat"),
        "lon": data.get("lon"),
        "country_code": data.get("country_code"),
        "timezone": data.get("timezone")
    }
    
    for k, v in top_level_cols.items():
        df[k] = v
    
    cols_order = ["city", "lat", "lon", "country_code", "datetime", "temp", 
                  "description", "code", "timezone"]
    df = df[[c for c in cols_order if c in df.columns]]

df
api1 = df.copy()

# %%
api1

# %% [markdown]
# ### Second api

# %%
"""
city
lat
log
country
datetime
temperature
timezone
"""

# %%
data = {
	"latitude": -23.5,
	"longitude": -46.5,
	"generationtime_ms": 0.03039836883544922,
	"utc_offset_seconds": 0,
	"timezone": "GMT",
	"timezone_abbreviation": "GMT",
	"elevation": 745.0,
	"hourly_units": {
		"time": "iso8601",
		"temperature_2m": "°C",
		"cloud_cover": "%"
	},
	"hourly": {
		"time": [
			"2025-11-18T00:00",
			"2025-11-18T01:00",
			"2025-11-18T02:00",
			"2025-11-18T03:00",
			"2025-11-18T04:00",
			"2025-11-18T05:00",
			"2025-11-18T06:00",
			"2025-11-18T07:00",
			"2025-11-18T08:00",
			"2025-11-18T09:00",
			"2025-11-18T10:00",
			"2025-11-18T11:00",
			"2025-11-18T12:00",
			"2025-11-18T13:00",
			"2025-11-18T14:00",
			"2025-11-18T15:00",
			"2025-11-18T16:00",
			"2025-11-18T17:00",
			"2025-11-18T18:00",
			"2025-11-18T19:00",
			"2025-11-18T20:00",
			"2025-11-18T21:00",
			"2025-11-18T22:00",
			"2025-11-18T23:00",
			"2025-11-19T00:00",
			"2025-11-19T01:00",
			"2025-11-19T02:00",
			"2025-11-19T03:00",
			"2025-11-19T04:00",
			"2025-11-19T05:00",
			"2025-11-19T06:00",
			"2025-11-19T07:00",
			"2025-11-19T08:00",
			"2025-11-19T09:00",
			"2025-11-19T10:00",
			"2025-11-19T11:00",
			"2025-11-19T12:00",
			"2025-11-19T13:00",
			"2025-11-19T14:00",
			"2025-11-19T15:00",
			"2025-11-19T16:00",
			"2025-11-19T17:00",
			"2025-11-19T18:00",
			"2025-11-19T19:00",
			"2025-11-19T20:00",
			"2025-11-19T21:00",
			"2025-11-19T22:00",
			"2025-11-19T23:00"
		],
		"temperature_2m": [
			20.7,
			20.5,
			20.5,
			20.6,
			20.3,
			20.0,
			19.7,
			19.8,
			19.6,
			19.7,
			20.0,
			20.6,
			21.8,
			22.2,
			23.0,
			23.8,
			23.0,
			22.8,
			22.3,
			20.9,
			20.5,
			20.0,
			19.4,
			19.5,
			19.1,
			18.7,
			18.1,
			17.4,
			16.6,
			16.1,
			15.1,
			14.9,
			14.6,
			14.7,
			15.9,
			17.5,
			19.5,
			20.9,
			22.2,
			23.3,
			24.0,
			24.5,
			24.3,
			24.0,
			23.2,
			20.9,
			18.7,
			17.3
		],
		"cloud_cover": [
			100,
			100,
			100,
			100,
			100,
			100,
			100,
			100,
			100,
			100,
			93,
			91,
			81,
			94,
			84,
			89,
			100,
			85,
			97,
			88,
			84,
			63,
			64,
			35,
			60,
			92,
			75,
			37,
			15,
			12,
			3,
			7,
			23,
			26,
			28,
			40,
			67,
			87,
			73,
			89,
			83,
			77,
			79,
			77,
			70,
			52,
			27,
			22
		]
	}
}

# %%
import pandas as pd

def transform_data_from_api_2(api_data_2):
    hourly = api_data_2.get("hourly", {})
    times = hourly.get("time", [])
    
    if not times:
        return pd.DataFrame()  # no data
    
    # Create DataFrame from hourly lists
    df = pd.DataFrame(hourly)
    
    # Rename columns to match first API
    df = df.rename(columns={
        "temperature_2m": "temp",
        "cloud_cover": "code",  # you can adjust if you want a different name
        "time": "datetime"
    })
    
    # Add top-level info
    df["lat"] = api_data_2.get("latitude")
    df["lon"] = api_data_2.get("longitude")
    df["city"] = api_data_2.get("city_name", None)  # city_name might not exist
    df["country_code"] = api_data_2.get("country_code", None)
    df["timezone"] = api_data_2.get("timezone")
    
    # Optionally, add description if needed (not in this API)
    if "description" not in df.columns:
        df["description"] = None
    
    # Reorder columns
    cols_order = ["city", "lat", "lon", "country_code", "datetime", "temp", 
                  "description",  "timezone"]
    df = df[[c for c in cols_order if c in df.columns]]
    df['city'] = 'São Paulo'
    return df


api2 = transform_data_from_api_2(data)

# %%
merged_df = api1.merge(
    api2,
    on=["city", "lat", "lon", "country_code", "datetime"],
    suffixes=("_api1", "_api2")
)

# %%
api1
# Out:
#          city      lat       lon country_code       datetime  temp  \
# 0   São Paulo -23.5475 -46.63611           BR  2025-11-18:00  22.0
# 1   São Paulo -23.5475 -46.63611           BR  2025-11-18:01  20.4
# 2   São Paulo -23.5475 -46.63611           BR  2025-11-18:02  20.0
# 3   São Paulo -23.5475 -46.63611           BR  2025-11-18:03  19.8
# 4   São Paulo -23.5475 -46.63611           BR  2025-11-18:04  19.6
# 5   São Paulo -23.5475 -46.63611           BR  2025-11-18:05  19.4
# 6   São Paulo -23.5475 -46.63611           BR  2025-11-18:06  19.2
# 7   São Paulo -23.5475 -46.63611           BR  2025-11-18:07  19.3
# 8   São Paulo -23.5475 -46.63611           BR  2025-11-18:08  19.4
# 9   São Paulo -23.5475 -46.63611           BR  2025-11-18:09  19.4
# 10  São Paulo -23.5475 -46.63611           BR  2025-11-18:10  20.0
# 11  São Paulo -23.5475 -46.63611           BR  2025-11-18:11  21.3
# 12  São Paulo -23.5475 -46.63611           BR  2025-11-18:12  21.5
# 13  São Paulo -23.5475 -46.63611           BR  2025-11-18:13  23.0
# 14  São Paulo -23.5475 -46.63611           BR  2025-11-18:14  23.2
# 15  São Paulo -23.5475 -46.63611           BR  2025-11-18:15  24.0
# 16  São Paulo -23.5475 -46.63611           BR  2025-11-18:16  23.4
# 17  São Paulo -23.5475 -46.63611           BR  2025-11-18:17  22.0
# 18  São Paulo -23.5475 -46.63611           BR  2025-11-18:18  22.0
# 19  São Paulo -23.5475 -46.63611           BR  2025-11-18:19  21.9
# 20  São Paulo -23.5475 -46.63611           BR  2025-11-18:20  21.0
# 21  São Paulo -23.5475 -46.63611           BR  2025-11-18:21  21.4
# 22  São Paulo -23.5475 -46.63611           BR  2025-11-18:22  22.0
# 23  São Paulo -23.5475 -46.63611           BR  2025-11-18:23  20.5
#
#          description  code           timezone
# 0    Overcast clouds   804  America/Sao_Paulo
# 1    Overcast clouds   804  America/Sao_Paulo
# 2    Overcast clouds   804  America/Sao_Paulo
# 3    Overcast clouds   804  America/Sao_Paulo
# 4      Broken clouds   803  America/Sao_Paulo
# 5    Overcast clouds   804  America/Sao_Paulo
# 6    Overcast clouds   804  America/Sao_Paulo
# 7    Overcast clouds   804  America/Sao_Paulo
# 8    Overcast clouds   804  America/Sao_Paulo
# 9      Broken clouds   803  America/Sao_Paulo
# 10   Overcast clouds   804  America/Sao_Paulo
# 11  Scattered clouds   802  America/Sao_Paulo
# 12   Overcast clouds   804  America/Sao_Paulo
# 13   Overcast clouds   804  America/Sao_Paulo
# 14   Overcast clouds   804  America/Sao_Paulo
# 15   Overcast clouds   804  America/Sao_Paulo
# 16        Light rain   500  America/Sao_Paulo
# 17           Drizzle   301  America/Sao_Paulo
# 18   Overcast clouds   804  America/Sao_Paulo
# 19           Drizzle   301  America/Sao_Paulo
# 20   Overcast clouds   804  America/Sao_Paulo
# 21     Broken clouds   803  America/Sao_Paulo
# 22     Broken clouds   803  America/Sao_Paulo
# 23     Broken clouds   803  America/Sao_Paulo

# %%
api1_teste = api1.copy()
api1_teste['hour'] = api1_teste['datetime'][0:-5]

# %%
api1
# Out:
#          city      lat       lon country_code       datetime  temp  \
# 0   São Paulo -23.5475 -46.63611           BR  2025-11-18:00  22.0
# 1   São Paulo -23.5475 -46.63611           BR  2025-11-18:01  20.4
# 2   São Paulo -23.5475 -46.63611           BR  2025-11-18:02  20.0
# 3   São Paulo -23.5475 -46.63611           BR  2025-11-18:03  19.8
# 4   São Paulo -23.5475 -46.63611           BR  2025-11-18:04  19.6
# 5   São Paulo -23.5475 -46.63611           BR  2025-11-18:05  19.4
# 6   São Paulo -23.5475 -46.63611           BR  2025-11-18:06  19.2
# 7   São Paulo -23.5475 -46.63611           BR  2025-11-18:07  19.3
# 8   São Paulo -23.5475 -46.63611           BR  2025-11-18:08  19.4
# 9   São Paulo -23.5475 -46.63611           BR  2025-11-18:09  19.4
# 10  São Paulo -23.5475 -46.63611           BR  2025-11-18:10  20.0
# 11  São Paulo -23.5475 -46.63611           BR  2025-11-18:11  21.3
# 12  São Paulo -23.5475 -46.63611           BR  2025-11-18:12  21.5
# 13  São Paulo -23.5475 -46.63611           BR  2025-11-18:13  23.0
# 14  São Paulo -23.5475 -46.63611           BR  2025-11-18:14  23.2
# 15  São Paulo -23.5475 -46.63611           BR  2025-11-18:15  24.0
# 16  São Paulo -23.5475 -46.63611           BR  2025-11-18:16  23.4
# 17  São Paulo -23.5475 -46.63611           BR  2025-11-18:17  22.0
# 18  São Paulo -23.5475 -46.63611           BR  2025-11-18:18  22.0
# 19  São Paulo -23.5475 -46.63611           BR  2025-11-18:19  21.9
# 20  São Paulo -23.5475 -46.63611           BR  2025-11-18:20  21.0
# 21  São Paulo -23.5475 -46.63611           BR  2025-11-18:21  21.4
# 22  São Paulo -23.5475 -46.63611           BR  2025-11-18:22  22.0
# 23  São Paulo -23.5475 -46.63611           BR  2025-11-18:23  20.5
#
#          description  code           timezone
# 0    Overcast clouds   804  America/Sao_Paulo
# 1    Overcast clouds   804  America/Sao_Paulo
# 2    Overcast clouds   804  America/Sao_Paulo
# 3    Overcast clouds   804  America/Sao_Paulo
# 4      Broken clouds   803  America/Sao_Paulo
# 5    Overcast clouds   804  America/Sao_Paulo
# 6    Overcast clouds   804  America/Sao_Paulo
# 7    Overcast clouds   804  America/Sao_Paulo
# 8    Overcast clouds   804  America/Sao_Paulo
# 9      Broken clouds   803  America/Sao_Paulo
# 10   Overcast clouds   804  America/Sao_Paulo
# 11  Scattered clouds   802  America/Sao_Paulo
# 12   Overcast clouds   804  America/Sao_Paulo
# 13   Overcast clouds   804  America/Sao_Paulo
# 14   Overcast clouds   804  America/Sao_Paulo
# 15   Overcast clouds   804  America/Sao_Paulo
# 16        Light rain   500  America/Sao_Paulo
# 17           Drizzle   301  America/Sao_Paulo
# 18   Overcast clouds   804  America/Sao_Paulo
# 19           Drizzle   301  America/Sao_Paulo
# 20   Overcast clouds   804  America/Sao_Paulo
# 21     Broken clouds   803  America/Sao_Paulo
# 22     Broken clouds   803  America/Sao_Paulo
# 23     Broken clouds   803  America/Sao_Paulo

# %%
api2
# Out:
#         city   lat   lon country_code          datetime  temp description  \
# 0   São Pulo -23.5 -46.5         None  2025-11-18T00:00  20.7        None
# 1   São Pulo -23.5 -46.5         None  2025-11-18T01:00  20.5        None
# 2   São Pulo -23.5 -46.5         None  2025-11-18T02:00  20.5        None
# 3   São Pulo -23.5 -46.5         None  2025-11-18T03:00  20.6        None
# 4   São Pulo -23.5 -46.5         None  2025-11-18T04:00  20.3        None
# 5   São Pulo -23.5 -46.5         None  2025-11-18T05:00  20.0        None
# 6   São Pulo -23.5 -46.5         None  2025-11-18T06:00  19.7        None
# 7   São Pulo -23.5 -46.5         None  2025-11-18T07:00  19.8        None
# 8   São Pulo -23.5 -46.5         None  2025-11-18T08:00  19.6        None
# 9   São Pulo -23.5 -46.5         None  2025-11-18T09:00  19.7        None
# 10  São Pulo -23.5 -46.5         None  2025-11-18T10:00  20.0        None
# 11  São Pulo -23.5 -46.5         None  2025-11-18T11:00  20.6        None
# 12  São Pulo -23.5 -46.5         None  2025-11-18T12:00  21.8        None
# 13  São Pulo -23.5 -46.5         None  2025-11-18T13:00  22.2        None
# 14  São Pulo -23.5 -46.5         None  2025-11-18T14:00  23.0        None
# 15  São Pulo -23.5 -46.5         None  2025-11-18T15:00  23.8        None
# 16  São Pulo -23.5 -46.5         None  2025-11-18T16:00  23.0        None
# 17  São Pulo -23.5 -46.5         None  2025-11-18T17:00  22.8        None
# 18  São Pulo -23.5 -46.5         None  2025-11-18T18:00  22.3        None
# 19  São Pulo -23.5 -46.5         None  2025-11-18T19:00  20.9        None
# 20  São Pulo -23.5 -46.5         None  2025-11-18T20:00  20.5        None
# 21  São Pulo -23.5 -46.5         None  2025-11-18T21:00  20.0        None
# 22  São Pulo -23.5 -46.5         None  2025-11-18T22:00  19.4        None
# 23  São Pulo -23.5 -46.5         None  2025-11-18T23:00  19.5        None
# 24  São Pulo -23.5 -46.5         None  2025-11-19T00:00  19.1        None
# 25  São Pulo -23.5 -46.5         None  2025-11-19T01:00  18.7        None
# 26  São Pulo -23.5 -46.5         None  2025-11-19T02:00  18.1        None
# 27  São Pulo -23.5 -46.5         None  2025-11-19T03:00  17.4        None
# 28  São Pulo -23.5 -46.5         None  2025-11-19T04:00  16.6        None
# 29  São Pulo -23.5 -46.5         None  2025-11-19T05:00  16.1        None
# 30  São Pulo -23.5 -46.5         None  2025-11-19T06:00  15.1        None
# 31  São Pulo -23.5 -46.5         None  2025-11-19T07:00  14.9        None
# 32  São Pulo -23.5 -46.5         None  2025-11-19T08:00  14.6        None
# 33  São Pulo -23.5 -46.5         None  2025-11-19T09:00  14.7        None
# 34  São Pulo -23.5 -46.5         None  2025-11-19T10:00  15.9        None
# 35  São Pulo -23.5 -46.5         None  2025-11-19T11:00  17.5        None
# 36  São Pulo -23.5 -46.5         None  2025-11-19T12:00  19.5        None
# 37  São Pulo -23.5 -46.5         None  2025-11-19T13:00  20.9        None
# 38  São Pulo -23.5 -46.5         None  2025-11-19T14:00  22.2        None
# 39  São Pulo -23.5 -46.5         None  2025-11-19T15:00  23.3        None
# 40  São Pulo -23.5 -46.5         None  2025-11-19T16:00  24.0        None
# 41  São Pulo -23.5 -46.5         None  2025-11-19T17:00  24.5        None
# 42  São Pulo -23.5 -46.5         None  2025-11-19T18:00  24.3        None
# 43  São Pulo -23.5 -46.5         None  2025-11-19T19:00  24.0        None
# 44  São Pulo -23.5 -46.5         None  2025-11-19T20:00  23.2        None
# 45  São Pulo -23.5 -46.5         None  2025-11-19T21:00  20.9        None
# 46  São Pulo -23.5 -46.5         None  2025-11-19T22:00  18.7        None
# 47  São Pulo -23.5 -46.5         None  2025-11-19T23:00  17.3        None
#
#    timezone
# 0       GMT
# 1       GMT
# 2       GMT
# 3       GMT
# 4       GMT
# 5       GMT
# 6       GMT
# 7       GMT
# 8       GMT
# 9       GMT
# 10      GMT
# 11      GMT
# 12      GMT
# 13      GMT
# 14      GMT
# 15      GMT
# 16      GMT
# 17      GMT
# 18      GMT
# 19      GMT
# 20      GMT
# 21      GMT
# 22      GMT
# 23      GMT
# 24      GMT
# 25      GMT
# 26      GMT
# 27      GMT
# 28      GMT
# 29      GMT
# 30      GMT
# 31      GMT
# 32      GMT
# 33      GMT
# 34      GMT
# 35      GMT
# 36      GMT
# 37      GMT
# 38      GMT
# 39      GMT
# 40      GMT
# 41      GMT
# 42      GMT
# 43      GMT
# 44      GMT
# 45      GMT
# 46      GMT
# 47      GMT
